# %%
#config box

d = {"key": "val", "key1": "val1"}

# %%
d['key1']
# Out:
# 'val1'

# %%
from box import ConfigBox

# %%
d2 = ConfigBox ({"key": "val", "key1": "val1"})

# %%
d.key1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 d.key1
#
# AttributeError: 'dict' object has no attribute 'key1'

# %%
d2.key1
# Out:
# 'val1'

# %%
type(d2)
# Out:
# box.config_box.ConfigBox

# %%
type(d)
# Out:
# dict

# %%
#ensure annotations

def get_product(x:int, y: int) -> int:
                return x*y

# %%
get_product(x=5, y=45)
# Out:
# 225

# %%
get_product(x=54, y="q")
# Out:
# 'qqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqq'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations

def get_product(x:int, y: int) -> int:
                return x*y

# %%
get_product(x=54, y="q")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 get_product(x=54, y="q")
#
# File c:\Users\HP\anaconda3\envs\renal_tumour_analysis\Lib\site-packages\ensure\main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x0000026C7D8EAB60> does not match annotation type <class 'int'>

# %%
get_product(x=5, y=45)
# Out:
# 225

# %% [markdown]
# #Ensure annotation is used to make sure that a certain data type is preserved for the computation and errors are flagge

# %% [markdown]
# ## Download Data from Google Drive

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1TuNYhoDmnEpdAIjRJelYoPs4lSYtnAsr/view?usp=sharing"

# %%
url.split("/")
# Out:
# ['https:',
#  '',
#  'drive.google.com',
#  'file',
#  'd',
#  '1TuNYhoDmnEpdAIjRJelYoPs4lSYtnAsr',
#  'view?usp=sharing']

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1TuNYhoDmnEpdAIjRJelYoPs4lSYtnAsr'

# %%
#file_id = file_id2.split("?")[-2]
#file_id

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "renal_CT_scan.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1TuNYhoDmnEpdAIjRJelYoPs4lSYtnAsr
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1TuNYhoDmnEpdAIjRJelYoPs4lSYtnAsr&confirm=t&uuid=1ea447fb-2db3-4709-8561-6cc01b9cf301
# To: c:\Users\HP\Documents\renal_tumour_project\research\renal_CT_scan.zip
# 100%|██████████| 1.63G/1.63G [02:15<00:00, 12.0MB/s]
# 'renal_CT_scan.zip'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
